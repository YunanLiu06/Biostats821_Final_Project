# %%
import pandas as pd
import numpy as np
import sqlite3

# %% [markdown]
# ### Data source
# CDC: https://data.cdc.gov/Flu-Vaccinations/Vaccines-gov-Flu-vaccinating-provider-locations/bugr-bbfr
#
# ### Information
# The Vaccines.gov dataset includes provider information for flu vaccine provider locations in the U.S. Vaccines.gov is powered by VaccineFinder.
#
# ### Suggestions on building functions
# 1. Browsing: 1) input `number` **(not that meaningful?)**
#
#                 ----> number of rows in the dataset
# 2. Searching: input `state+city`
#
#                     ---> find flu vaccine provider in the same city(name, location street, open hours, other information)
#
# 3. Searching (auto-completion): input `part of provider's name` (loc_name)
#
#                                 ----> whole provider's name + relevant information(location, open hours, other information)

# %% [markdown]
# ## EDA

# %%
vaccines_data = pd.read_csv("/Users/liuxiaoquan/Documents/GitHub/Biostats821_Final_Project/data/Vaccines.gov__Flu_vaccinating_provider_locations.csv", low_memory=False)
vaccines_data.head()
# Out:
#                  provider_location_guid    loc_store_no       loc_phone  \
# 0  70d24f31-f2c4-4e08-b1b6-afbbd83947a2  Not applicable  (580) 924-4285
# 1  9cd97dd4-2196-4585-a1e5-c1ed72e94510  Not applicable  (304) 682-0444
# 2  328f435a-3fe8-4262-bd00-17eab759ced2  Not applicable  (931) 647-6561
# 3  a499a795-2e5c-4f7f-a3a2-e3042bd0e813  Not applicable    215-735-5600
# 4  eaf46825-8bba-4f27-ba26-7f9fb787030d       MS1005662  (718) 433-9800
#
#                         loc_name            loc_admin_street1  \
# 0             BRYAN CHD - DURANT           1524 W. Chuckwa DR
# 1          Renegade Pharmacy Inc              18 Logan Street
# 2            ST. BETHLEHEM DRUGS  800 WEATHERLY DR SUITE 101A
# 3         Center City Pediatrics            1740 South Street
# 4  Vida Sana Pharmacy #MS1005662                8820 37th ave
#
#           loc_admin_street2   loc_admin_city loc_admin_state loc_admin_zip  \
# 0                       NaN           Durant              OK         74701
# 1                       NaN           Oceana              WV         24870
# 2                       NaN      CLARKSVILLE              TN         37043
# 3  1740 South St  Suite 200     Philadelphia              PA         19146
# 4                       NaN  Jackson Heights              NY    11372-7737
#
#   sunday_hours  ... insurance_accepted walkins_accepted  \
# 0          NaN  ...               True             True
# 1       Closed  ...               True             True
# 2       Closed  ...               True             True
# 3          NaN  ...                NaN              NaN
# 4       Closed  ...               True             True
#
#                                       provider_notes  \
# 0                                                NaN
# 1  Covid 19 vaccinations given Mon.-Wed.-Fri betw...
# 2  Please call to schedule an appointment ONLY if...
# 3                                                NaN
# 4                                                NaN
#
#                            searchable_name in_stock supply_level  \
# 0                                 Flu Shot     True           -1
# 1  Flu Shot (65+, high-dose or adjuvanted)    False            3
# 2                      Flu Shot (Egg free)    False           -1
# 3                                 Flu Shot     True            4
# 4  Flu Shot (65+, high-dose or adjuvanted)     True            4
#
#   quantity_last_updated   latitude  longitude  category
# 0            2022-10-25  34.008567 -96.382197  seasonal
# 1            2022-12-23  37.692379 -81.634361  seasonal
# 2            2022-12-08  36.574125 -87.285068  seasonal
# 3            2022-12-19  39.944177 -75.171724  seasonal
# 4            2023-01-02  40.750210 -73.878084  seasonal
#
# [5 rows x 28 columns]

# %%
vaccines_data.shape
# Out:
# (245118, 28)

# %%
# count the number of searchable_name
vaccines_data['searchable_name'].value_counts().to_frame()
# Out:
#                                          searchable_name
# Flu Shot                                          116706
# Flu Shot (Egg free)                                63137
# Flu Shot (65+, high-dose or adjuvanted)            58364
# Flu Nasal Spray                                     6911

# %%
# vaccinate provider in Durham, NC
VAC = vaccines_data.loc[vaccines_data['loc_admin_city'] == 'Durham',:]
VAC.head()
# Out:
#                      provider_location_guid loc_store_no       loc_phone  \
# 4108   2dd9f103-5118-42e1-986c-21229835853d      10-4831      9194898160
# 4985   824308c3-7468-4c8b-90c8-c0a57f674454         1817  (919) 598-0803
# 4986   824308c3-7468-4c8b-90c8-c0a57f674454         1817  (919) 598-0803
# 21086  824308c3-7468-4c8b-90c8-c0a57f674454         1817  (919) 598-0803
# 50223  d350fa41-8714-4e81-bed7-a4a310dfce3d          420    919-620-1947
#
#                               loc_name             loc_admin_street1  \
# 4108                Sams Club #10-4831  4005 Durham Chapel Hill Blvd
# 4985   Publix Super Markets Inc. #1817               1065 Yunus Road
# 4986   Publix Super Markets Inc. #1817               1065 Yunus Road
# 21086  Publix Super Markets Inc. #1817               1065 Yunus Road
# 50223                   Food Lion #420               3808 Guess Road
#
#       loc_admin_street2 loc_admin_city loc_admin_state loc_admin_zip  \
# 4108                NaN         Durham              NC    27707-2516
# 4985                NaN         Durham              NC    27703-7200
# 4986                NaN         Durham              NC    27703-7200
# 21086               NaN         Durham              NC    27703-7200
# 50223               NaN         Durham              NC         27705
#
#            sunday_hours  ... insurance_accepted walkins_accepted  \
# 4108                NaN  ...               True             True
# 4985   11:00AM - 6:00PM  ...               True             True
# 4986   11:00AM - 6:00PM  ...               True             True
# 21086  11:00AM - 6:00PM  ...               True             True
# 50223               NaN  ...               True             True
#
#       provider_notes      searchable_name in_stock supply_level  \
# 4108             NaN      Flu Nasal Spray    False           -1
# 4985             NaN             Flu Shot    False           -1
# 4986             NaN             Flu Shot    False           -1
# 21086            NaN  Flu Shot (Egg free)    False           -1
# 50223            NaN  Flu Shot (Egg free)    False           -1
#
#       quantity_last_updated   latitude  longitude  category
# 4108             2023-03-28  35.967432 -78.958222  seasonal
# 4985             2023-04-06  35.940518 -78.853660  seasonal
# 4986             2023-04-06  35.940518 -78.853660  seasonal
# 21086            2023-04-06  35.940518 -78.853660  seasonal
# 50223            2023-04-07  36.058269 -78.928471  seasonal
#
# [5 rows x 28 columns]

# %%
vaccines_data['category'].value_counts().to_frame()
# Out:
#           category
# seasonal    245118

# %%
vaccines_data['supply_level'].value_counts().to_frame()
# Out:
#     supply_level
# -1        207258
#  4         28463
#  3          8088
#  1          1309

# %%
vaccines_data.columns
# Out:
# Index(['provider_location_guid', 'loc_store_no', 'loc_phone', 'loc_name',
#        'loc_admin_street1', 'loc_admin_street2', 'loc_admin_city',
#        'loc_admin_state', 'loc_admin_zip', 'sunday_hours', 'monday_hours',
#        'tuesday_hours', 'wednesday_hours', 'thursday_hours', 'friday_hours',
#        'saturday_hours', 'web_address', 'pre_screen', 'insurance_accepted',
#        'walkins_accepted', 'provider_notes', 'searchable_name', 'in_stock',
#        'supply_level', 'quantity_last_updated', 'latitude', 'longitude',
#        'category'],
#       dtype='object')

# %%
# drop the columns that are not needed 'loc_store_no', 'latitude', 'longitude','category'
vac_new = vaccines_data.drop(['loc_store_no', 'latitude', 'longitude','category','supply_level'], axis=1)
vac_new.shape
# Out:
# (245118, 23)

# %%
vac_new['sunday_hours'] = 'sunday_hours:  '+ vac_new['sunday_hours'].astype(str) + '  |  '
vac_new['monday_hours'] = 'monday_hours:  '+ vac_new['monday_hours'].astype(str) + '  |  '
vac_new['tuesday_hours'] = 'tuesday_hours:  '+ vac_new['tuesday_hours'].astype(str) + '  |  '
vac_new['wednesday_hours'] = 'wednesday_hours:  '+ vac_new['wednesday_hours'].astype(str) + '  |  '
vac_new['thursday_hours'] = 'thursday_hours:  '+ vac_new['thursday_hours'].astype(str) + '  |  '
vac_new['friday_hours'] = 'friday_hours:  '+ vac_new['friday_hours'].astype(str) + '  |  '
vac_new['saturday_hours'] = 'saturday_hours:  '+ vac_new['saturday_hours'].astype(str)

# combine the hours into one column
vac_new['opening_hours'] = vac_new['sunday_hours'] + vac_new['monday_hours'] + vac_new[
    'tuesday_hours'] + vac_new['wednesday_hours'] + vac_new['thursday_hours'] + vac_new[
    'friday_hours'] + vac_new['saturday_hours']

# %%
print(vac_new['opening_hours'].loc[0])
# Out:
# sunday_hours:  nan  |  monday_hours:  8:00 AM - 5:00 PM  |  tuesday_hours:  8:00 AM - 5:00 PM  |  wednesday_hours:  8:00 AM - 5:00 PM  |  thursday_hours:  8:00 AM - 5:00 PM  |  friday_hours:  8:00 AM - 5:00 PM  |  saturday_hours:  nan

# %%
vac_new['opening_hours'].head()
# Out:
# 0    sunday_hours:  nan  |  monday_hours:  8:00 AM ...
# 1    sunday_hours:  Closed  |  monday_hours:  8:30 ...
# 2    sunday_hours:  Closed  |  monday_hours:  9:00 ...
# 3    sunday_hours:  nan  |  monday_hours:  nan  |  ...
# 4    sunday_hours:  Closed  |  monday_hours:  9:30 ...
# Name: opening_hours, dtype: object

# %%
vac_new.drop(['sunday_hours', 'monday_hours', 'tuesday_hours','wednesday_hours','thursday_hours','friday_hours','saturday_hours'], axis=1, inplace=True)
vac_new.columns
# Out:
# Index(['provider_location_guid', 'loc_phone', 'loc_name', 'loc_admin_street1',
#        'loc_admin_street2', 'loc_admin_city', 'loc_admin_state',
#        'loc_admin_zip', 'web_address', 'pre_screen', 'insurance_accepted',
#        'walkins_accepted', 'provider_notes', 'searchable_name', 'in_stock',
#        'quantity_last_updated', 'opening_hours'],
#       dtype='object')

# %%
# check data type
vac_new.dtypes
# Out:
# provider_location_guid    object
# loc_phone                 object
# loc_name                  object
# loc_admin_street1         object
# loc_admin_street2         object
# loc_admin_city            object
# loc_admin_state           object
# loc_admin_zip             object
# web_address               object
# pre_screen                object
# insurance_accepted        object
# walkins_accepted          object
# provider_notes            object
# searchable_name           object
# in_stock                    bool
# quantity_last_updated     object
# opening_hours             object
# dtype: object

# %%
# save the new dataframe to a csv file
# vac_new.to_csv('vaccines_processed.csv', index=False)

# %% [markdown]
# # Subset for NC

# %%
# subset for NC
vac_NC = vac_new.loc[vac_new['loc_admin_state'] == 'NC',:]
vac_NC.sample(5)
# Out:
#                       provider_location_guid       loc_phone  \
# 118779  10078d22-eb0d-46b8-a5e2-4c7297c3e562    704-889-2029
# 191688  177728b9-be6c-47a5-b32e-fd12ef85c07f    252-293-0255
# 234559  d17a76f6-9679-491f-94f6-ecf4cbe123ad    828-464-1354
# 94484   32a094e8-325b-40ac-967d-9fd69500d17e      7047323090
# 36953   a57259d4-109c-467e-bee8-de97d182da02  (919) 855-5694
#
#                          loc_name              loc_admin_street1  \
# 118779       Walgreens Co. #19877  10020 PINEVILLE MATTHEWS ROAD
# 191688        Walgreens Co. #6926           3001 NC HIGHWAY 42 W
# 234559             Bowman Drug Co         126 FIRST AVENUE SOUTH
# 94484        Walmart Inc #10-1209            306 N Generals Blvd
# 36953   CVS Pharmacy, Inc. #02714           3500 WAKE FOREST RD.
#
#        loc_admin_street2 loc_admin_city loc_admin_state loc_admin_zip  \
# 118779                 -      PINEVILLE              NC    28134-7552
# 191688                 -         WILSON              NC    27893-7735
# 234559               NaN        CONOVER              NC         28613
# 94484                NaN     Lincolnton              NC    28092-3557
# 36953                NaN        RALEIGH              NC         27609
#
#                                               web_address  \
# 118779                          https://www.walgreens.com
# 191688                          https://www.walgreens.com
# 234559                 https://healthmartcovidvaccine.com
# 94484                  https://www.walmart.com/store/1209
# 36953   https://www.cvs.com/store-locator/details-dire...
#
#                                                pre_screen insurance_accepted  \
# 118779  https://www.walgreens.com/findcare/vaccination...               True
# 191688  https://www.walgreens.com/findcare/vaccination...               True
# 234559                 https://healthmartcovidvaccine.com               True
# 94484                                                 NaN               True
# 36953    https://www.cvs.com/immunizations/get-vaccinated               True
#
#        walkins_accepted                                     provider_notes  \
# 118779             True  Appointments are not required to receive a Flu...
# 191688             True  Appointments are not required to receive a Flu...
# 234559            False  Scheduling an appointment is recommended. Plea...
# 94484              True                                                NaN
# 36953              True  It is highly recommended to make an appointmen...
#
#             searchable_name  in_stock quantity_last_updated  \
# 118779             Flu Shot      True            2023-04-03
# 191688             Flu Shot      True            2023-04-03
# 234559  Flu Shot (Egg free)     False            2023-04-07
# 94484       Flu Nasal Spray     False            2023-03-28
# 36953   Flu Shot (Egg free)     False            2023-04-06
#
#                                             opening_hours
# 118779  sunday_hours:  12:00AM - 12:00AM  |  monday_ho...
# 191688  sunday_hours:  12:00AM - 12:00AM  |  monday_ho...
# 234559  sunday_hours:  nan  |  monday_hours:  10:00 AM...
# 94484   sunday_hours:  11:00 AM - 1:30PM, 2:00 PM - 5:...
# 36953   sunday_hours:  11:00AM-05:00PM  |  monday_hour...

# %% [markdown]
# ## Duplicates

# %%
print(f"Number of duplicates: {vac_NC.duplicated().sum()}")

# drop duplicates
vac_NC = vac_NC.drop_duplicates()

assert vac_NC.duplicated().sum() == 0
print(f"Number of duplicates now: {vac_NC.duplicated().sum()}")
# Out:
# Number of duplicates: 3198
# Number of duplicates now: 0

# %% [markdown]
# ## Missings

# %%
for i in vac_NC.columns:
    print(f"Column {i} has {vac_NC[i].isnull().sum()} null values, percentage: {round(vac_NC[i].isnull().sum()/vac_NC.shape[0], 2)}")
# Out:
# Column provider_location_guid has 0 null values, percentage: 0.0
# Column loc_phone has 0 null values, percentage: 0.0
# Column loc_name has 0 null values, percentage: 0.0
# Column loc_admin_street1 has 0 null values, percentage: 0.0
# Column loc_admin_street2 has 4102 null values, percentage: 0.79
# Column loc_admin_city has 0 null values, percentage: 0.0
# Column loc_admin_state has 0 null values, percentage: 0.0
# Column loc_admin_zip has 0 null values, percentage: 0.0
# Column web_address has 6 null values, percentage: 0.0
# Column pre_screen has 1228 null values, percentage: 0.24
# Column insurance_accepted has 6 null values, percentage: 0.0
# Column walkins_accepted has 6 null values, percentage: 0.0
# Column provider_notes has 1874 null values, percentage: 0.36
# Column searchable_name has 0 null values, percentage: 0.0
# Column in_stock has 0 null values, percentage: 0.0
# Column quantity_last_updated has 0 null values, percentage: 0.0
# Column opening_hours has 0 null values, percentage: 0.0

# %% [markdown]
# loc_admin_street2 has too many missing values -- drop the column

# %%
vac_NC = vac_NC.drop(['loc_admin_street2'], axis=1)

# %%
# replace missing values as "Not Available"
vac_NC['pre_screen'] = vac_NC['pre_screen'].fillna('Not Available')
vac_NC['provider_notes'] = vac_NC['provider_notes'].fillna('Not Available')
vac_NC['web_address'] = vac_NC['web_address'].fillna('Not Available')
vac_NC['insurance_accepted'] = vac_NC['insurance_accepted'].fillna('Not Available')
vac_NC['walkins_accepted'] = vac_NC['walkins_accepted'].fillna('Not Available')

assert vac_NC.isnull().sum().sum() == 0

# %% [markdown]
# ## Format phone number

# %%
# format phone number as xxx-xxx-xxxx
vac_NC['loc_phone'] = vac_NC['loc_phone'].str.extractall(r'(\d)').unstack().apply(lambda x: ''.join(x), axis=1)
vac_NC['loc_phone'] = vac_NC['loc_phone'].str.replace(r'(\d{3})(\d{3})(\d{4})', r'\1-\2-\3')
vac_NC.sample(5)
# Out:
# /var/folders/sg/9df1z7l9473gcyg7yjh1kzcc0000gn/T/ipykernel_93811/819198046.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   vac_NC['loc_phone'] = vac_NC['loc_phone'].str.replace(r'(\d{3})(\d{3})(\d{4})', r'\1-\2-\3')
#                       provider_location_guid     loc_phone  \
# 82543   50637dac-a155-4631-82e2-a08cf0815116  704-366-2344
# 83397   c84653dc-9b45-4be5-a87c-e9f161b14d83  704-810-3681
# 221289  368fe900-f7d4-4da9-a168-7887ea475126  704-392-3338
# 144939  8368b62c-0926-4fb8-8629-6e4053bb890b  919-603-1469
# 175612  631c226f-0c4a-4366-b09c-087f82dff951  828-393-6925
#
#                                loc_name            loc_admin_street1  \
# 82543              Walgreens Co. #18352  334 SOUTH SHARON AMITY ROAD
# 83397         CVS Pharmacy, Inc. #04490             2580 COURT DRIVE
# 221289             Walmart Inc #10-5481          9820 Callabridge Ct
# 144939             Walgreens Co. #12630             201 HILLSBORO ST
# 175612  Publix Super Markets Inc. #1586           635 Greenville Hwy
#
#         loc_admin_city loc_admin_state loc_admin_zip  \
# 82543        CHARLOTTE              NC    28211-2806
# 83397         GASTONIA              NC         28054
# 221289       Charlotte              NC    28216-7669
# 144939          OXFORD              NC    27565-3256
# 175612  Hendersonville              NC         28792
#
#                                               web_address  \
# 82543                           https://www.walgreens.com
# 83397   https://www.cvs.com/store-locator/details-dire...
# 221289                 https://www.walmart.com/store/5481
# 144939                          https://www.walgreens.com
# 175612  https://www.publix.com/pharmacy/pharmacy-servi...
#
#                                                pre_screen insurance_accepted  \
# 82543   https://www.walgreens.com/findcare/vaccination...               True
# 83397    https://www.cvs.com/immunizations/get-vaccinated               True
# 221289                                      Not Available               True
# 144939  https://www.walgreens.com/findcare/vaccination...               True
# 175612                    https://www.publix.com/vaccines               True
#
#        walkins_accepted                                     provider_notes  \
# 82543              True  Appointments are not required to receive a Flu...
# 83397              True  It is highly recommended to make an appointmen...
# 221289             True                                      Not Available
# 144939             True  Appointments are not required to receive a Flu...
# 175612             True                                      Not Available
#
#                                 searchable_name  in_stock  \
# 82543                                  Flu Shot      True
# 83397                       Flu Shot (Egg free)     False
# 221289  Flu Shot (65+, high-dose or adjuvanted)      True
# 144939                                 Flu Shot      True
# 175612                      Flu Shot (Egg free)     False
#
#        quantity_last_updated  \
# 82543             2023-04-03
# 83397             2023-04-06
# 221289            2023-03-28
# 144939            2023-04-03
# 175612            2023-04-06
#
#                                             opening_hours
# 82543   sunday_hours:  10:00AM - 06:00PM  |  monday_ho...
# 83397   sunday_hours:  10:00AM-06:00PM  |  monday_hour...
# 221289  sunday_hours:  11:00 AM - 5:00 PM  |  monday_h...
# 144939  sunday_hours:  10:00AM - 06:00PM  |  monday_ho...
# 175612  sunday_hours:  11:00AM - 6:00PM  |  monday_hou...

# %%
# save to a csv file
vac_NC.to_csv('/Users/liuxiaoquan/Documents/GitHub/Biostats821_Final_Project/data/vaccines_NC.csv', index=False)

# %% [markdown]
# ## Create Database Using SQLite

# %%
connection = sqlite3.connect("/Users/liuxiaoquan/Documents/GitHub/Biostats821_Final_Project/database/Flu_Vaccines_Provider_NC.db")
cursor = connection.cursor()
cursor.execute("DROP TABLE IF EXISTS Vaccines")

# create a table

cursor.execute("""CREATE TABLE Vaccines (
guid VARCHAR, phone_number VARCHAR, provider_name VARCHAR, street_address1 VARCHAR,
city VARCHAR, state VARCHAR, zip VARCHAR, website VARCHAR, 
pre_sreening_required VARCHAR, insurance_accepted VARCHAR, walkins_accepted VARCHAR, 
provider_notes VARCHAR, searchable_name VARCHAR, in_stock VARCHAR, 
quantity_last_updated VARCHAR, hours VARCHAR)""") 

# insert data into the table
with open('/Users/liuxiaoquan/Documents/GitHub/Biostats821_Final_Project/data/vaccines_NC.csv', 'r') as f:
    next(f) # Skip the header row.
    for line in f:
        vaccines_line = line.strip().split(',')
        cursor.execute("INSERT INTO Vaccines VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)",
                          vaccines_line[0:16])

connection.commit()
connection.close()

# %%
# select data from the table
connection = sqlite3.connect("/Users/liuxiaoquan/Documents/GitHub/Biostats821_Final_Project/database/Flu_Vaccines_Provider_NC.db")
cursor = connection.cursor()
cursor.execute("SELECT * FROM Vaccines LIMIT 5")
data = cursor.fetchall()
print(data[0])
# Out:
# ('0a2bcf19-9d62-41e0-b22e-cc6b6c371b63', '910-278-6050', 'Thomas Drugs #3438365', '7917 E OAK ISLAND DR', 'Oak Island', 'NC', '28465', 'Not Available', 'Not Available', 'Not Available', 'Not Available', 'Not Available', 'Flu Shot (Egg free)', 'False', '2023-01-09', 'sunday_hours:  nan  |  monday_hours:  nan  |  tuesday_hours:  nan  |  wednesday_hours:  nan  |  thursday_hours:  nan  |  friday_hours:  nan  |  saturday_hours:  nan')

# %%
vac_NC.iloc[0,:]
# Out:
# provider_location_guid                 0a2bcf19-9d62-41e0-b22e-cc6b6c371b63
# loc_phone                                                      910-278-6050
# loc_name                                              Thomas Drugs #3438365
# loc_admin_street1                                      7917 E OAK ISLAND DR
# loc_admin_city                                                   Oak Island
# loc_admin_state                                                          NC
# loc_admin_zip                                                         28465
# web_address                                                   Not Available
# pre_screen                                                    Not Available
# insurance_accepted                                            Not Available
# walkins_accepted                                              Not Available
# provider_notes                                                Not Available
# searchable_name                                         Flu Shot (Egg free)
# in_stock                                                              False
# quantity_last_updated                                            2023-01-09
# opening_hours             sunday_hours:  nan  |  monday_hours:  nan  |  ...
# Name: 30, dtype: object
